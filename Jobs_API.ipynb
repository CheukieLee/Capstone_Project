# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **JOBS API Implementation Using FLASK**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives
#
# You will be executing this code  so that the client application **Collecting Jobs API**  will be accessing this code executing on the server

# %%
# !pip install flask
#!pip install wget
# Out:
# Requirement already satisfied: flask in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (2.2.3)
# Requirement already satisfied: click>=8.0 in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from flask) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from flask) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from flask) (2.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from flask) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from importlib-metadata>=3.6.0->flask) (3.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from Jinja2>=3.0->flask) (2.1.2)

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: [https://www.kaggle.com/promptcloud/jobs-on-naukricom](https://www.kaggle.com/promptcloud/jobs-on-naukricom?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01) under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %%
#!wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json

# %%
import flask
from flask import request, jsonify
import requests
import re

def get_data(key,value,current):
    results = list()
    total = 0
    pattern_dict = {
        'C'      : '(C)',
        'C++'    : '(C\+\+)',
        'Java'   :'(Java)',
        'C#'     : '(C\#)',
        'Python' :'(Python)',
        'Scala' : '(Scala)',
        'Oracle' : '(Oracle)',
        'SQL Server': '(SQL Server)',
        'MySQL Server' :'(MySQL Server)',
        'PostgreSQL':'(PostgreSQL)',
        'MongoDB'    : '(MongoDB)',
        'JavaScript'    : '(JavaScript)',
        'Los Angeles' :'(Los Angeles)',
        'New York':'(New York)',
        'San Francisco':'(San Francisco)',
        'Washington DC':'(Washington DC)',
        'Seattle':'(Seattle)',
        'Austin':'(Austin)',
        'Detroit':'(Detroit)',
        }
    for rec in current:
        #print(rec[key])
        #print(type(rec[key]))
        #print(rec[key].find(value))
        #if rec[key].find(value) != -1:
        import re
        #reex_str = """(C)|(C\+\+)|(JavaScript)|(Java)|(C\#)|(Python)|(Scala)|(Oracle)|(SQL Server)|(MySQL Server)|(PostgreSQL)|(MongoDB)"""
        if re.search(pattern_dict[value],rec[key]) != None:
            results.append(rec)
            #total = total + 1
    return results

app = flask.Flask(__name__)

import json
data = None
with open('jobs.json',encoding='utf-8') as f:
    # returns JSON object as
    # a dictionary
    data = json.load(f)
    
    

@app.route('/', methods=['GET'])
def home():
    
    return '''<h1>Welcome to flask JOB search API</p>'''


@app.route('/data/all', methods=['GET'])
def api_all():
    return jsonify(data)


@app.route('/data', methods=['GET'])
def api_id():
    # Check if keys such as Job Title,KeySkills, Role Category and others  are provided as part of the URL.
    #  Assign the keys to the corresponding variables..
    # If no key is provided, display an error in the browser.
    res = None
    for req in request.args:
        
        if req == 'Job Title':
            key = 'Job Title'
        elif req == 'Job Experience Required' :
            key='Job Experience Required'
        elif req == 'Key Skills' :
            key='Key Skills'
            
        elif req == 'Role Category' :
            key='Role Category'
        elif req == 'Location' :
            key='Location'
        
        elif req == 'Functional Area' :
            key='Functional Area'
        
        elif req == 'Industry' :
            key='Industry'
        elif req == 'Role' :
            key='Role'
        elif req=="id":
             key="id"
        else:
            pass
    
        value = request.args[key]
        #print('Testing',key, value)
        if (res==None):
            res = get_data(key,value,data)
        else:
            res = get_data(key,value,res)
    #print('Res ',res)
    # Use the jsonify function from Flask to convert our list of
    # Python dictionaries to the JSON format.
    return jsonify(res)

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Apr/2023 08:12:37] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:12:37] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:13:01] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:26:52] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:28:26] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:30:32] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:30:54] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:31:37] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:36:06] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:38:46] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:39:44] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:41:40] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:48:21] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:05] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:05] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:06] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:07] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:07] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:34] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:34] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:34] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:34] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:34] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:35] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:35] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:35] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:35] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:35] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:35] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:35] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:58] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:58] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:58] "GET /data/all?Job%20Title=C++ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=Java HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=JavaScript HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=Scala HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=Oracle HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=SQL%20Server HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=MySQL%20Server HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:53:59] "GET /data/all?Job%20Title=PostgreSQL HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:54:00] "GET /data/all?Job%20Title=MongoDB HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:55:50] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:56:15] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:56:39] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:57:23] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:58:22] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 08:59:22] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:00:15] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:00:31] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:01:26] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:04:21] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:04:37] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:10:49] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:11:49] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:26:43] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:27:16] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:28:08] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:28:20] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:28:40] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:29:18] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:30:38] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:40:01] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:41:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:41:18] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Apr/2023 09:41:35] "GET /jobs.json HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Apr/2023 09:42:35] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:49:27] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:50:03] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:50:57] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:51:06] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:53:08] "GET /data/all?Job%20Title=Pyhton HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:53:30] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:53:53] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:54:43] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:56:15] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:56:15] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:56:15] "GET /data/all?Job%20Title=C++ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:56:42] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:56:43] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:56:43] "GET /data/all?Job%20Title=C++ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:56:59] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:57:00] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:57:00] "GET /data/all?Job%20Title=C++ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:57:44] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:57:44] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:57:44] "GET /data/all?Job%20Title=C++ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:58:34] "GET /data/all?Job%20Title=C++ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 09:59:14] "GET /data/all?Job%20Title=C%5C+%5C+ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:22] "GET /data/all?Job%20Title=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:22] "GET /data/all?Job%20Title=C%5C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:23] "GET /data/all?Job%20Title=C%5C+%5C+ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:23] "GET /data/all?Job%20Title=Java HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:23] "GET /data/all?Job%20Title=JavaScript HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:23] "GET /data/all?Job%20Title=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:23] "GET /data/all?Job%20Title=Scala HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:23] "GET /data/all?Job%20Title=Oracle HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:23] "GET /data/all?Job%20Title=SQL%20Server HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:24] "GET /data/all?Job%20Title=MySQL%20Server HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:24] "GET /data/all?Job%20Title=PostgreSQL HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:00:24] "GET /data/all?Job%20Title=MongoDB HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:02:13] "GET /data/all?location=Los%20Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:02:54] "GET /data/all?location=Los%20Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:04:03] "GET /data/all?location=Los%20Angeles HTTP/1.1" 200 -
# [2023-04-06 10:05:09,738] ERROR in app: Exception on /data [GET]
# Traceback (most recent call last):
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/var/folders/sn/c5c5ls6s4gz9tlfhfp7yxxl00000gq/T/ipykernel_1059/1696567210.py", line 96, in api_id
#     value = request.args[key]
# UnboundLocalError: local variable 'key' referenced before assignment
# 127.0.0.1 - - [06/Apr/2023 10:05:09] "GET /data?location=los%20Angeles HTTP/1.1" 500 -
# [2023-04-06 10:05:20,286] ERROR in app: Exception on /data [GET]
# Traceback (most recent call last):
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/var/folders/sn/c5c5ls6s4gz9tlfhfp7yxxl00000gq/T/ipykernel_1059/1696567210.py", line 96, in api_id
#     value = request.args[key]
# UnboundLocalError: local variable 'key' referenced before assignment
# 127.0.0.1 - - [06/Apr/2023 10:05:20] "GET /data?location=Los%20Angeles HTTP/1.1" 500 -
# [2023-04-06 10:05:33,888] ERROR in app: Exception on /data [GET]
# Traceback (most recent call last):
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/LCY/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "/var/folders/sn/c5c5ls6s4gz9tlfhfp7yxxl00000gq/T/ipykernel_1059/1696567210.py", line 96, in api_id
#     value = request.args[key]
# UnboundLocalError: local variable 'key' referenced before assignment
# 127.0.0.1 - - [06/Apr/2023 10:05:33] "GET /data?location=Los%20Angeles HTTP/1.1" 500 -
# 127.0.0.1 - - [06/Apr/2023 10:06:04] "GET /data/all HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:06:56] "GET /data?Location=Los%20Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:07:11] "GET /data/all?Location=Los%20Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:10:21] "GET /data/all?Location=New%20York HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:10:40] "GET /data/all?Location=Washingtion%20DC HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:10:55] "GET /data/all?Location=Washington%20DC HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:11:06] "GET /data/all?Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:43] "GET /data/all?Key%20Skills=C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:44] "GET /data/all?Key%20Skills=C%5C HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:44] "GET /data/all?Key%20Skills=C%5C+%5C+ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:44] "GET /data/all?Key%20Skills=Java HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:44] "GET /data/all?Key%20Skills=JavaScript HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:44] "GET /data/all?Key%20Skills=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:44] "GET /data/all?Key%20Skills=Scala HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:44] "GET /data/all?Key%20Skills=Oracle HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:45] "GET /data/all?Key%20Skills=SQL%20Server HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:45] "GET /data/all?Key%20Skills=MySQL%20Server HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:45] "GET /data/all?Key%20Skills=PostgreSQL HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Apr/2023 10:13:45] "GET /data/all?Key%20Skills=MongoDB HTTP/1.1" 200 -

# %% [markdown]
# ## Authors

# %% [markdown]
# Lakshmi Holla

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Malika Singla\
# Ayushi Jain

# %% [markdown]
# ## Changelog

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description      |
# | ----------------- | ------- | ------------- | ----------------------- |
# | 2022-01-03        | 0.1     | Lakshmi Holla | Created Initial Version |

# %% [markdown]
# Copyright © 2022 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
